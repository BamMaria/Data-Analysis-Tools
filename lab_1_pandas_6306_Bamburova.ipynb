# %% [markdown]
# # Лабораторная работа 1
# Pandas
#
# Выполнил: 6306,Бамбурова Мария Владимировна

# %% [markdown]
# 1 Считать в pandas DataFrame любой источник данных:  CSV, JSON, Excel-файл, HTML-таблицу, встроенный датасет sklearn. Опишите ваши данные, что обозначает каждый столбец, какого типа (категориальный, вещественный, целочисленный, бинарный) данный столбец, при необходимости для категориальных в том числе бинарных признаков привести расшифровку их значений. В общем, проведите "визуальный" анализ ваших данных.

# %%
 # !pip install opendatasets

# %%
import opendatasets as od

# %%
dataset='https://www.kaggle.com/datasets/deepu1109/star-dataset'

# %%
import os

# %%
od.download(dataset)

# %%
data_dir='.\star-dataset'

# %%
os.listdir(data_dir)
# Out:
# ['6 class csv.csv']

# %%
import pandas as pd

# %% [markdown]
# **Датасет содержит характеристики звёзд**

# %% [markdown]
# **Цель:**
# Цель создания набора данных - доказать, что звезды следуют определенному графику в небесном пространстве,специально называемому диаграммой Герцшпрунга-Рассела или просто HR-диаграммой,чтобы мы могли классифицировать звезды,нанося их характеристики на основе этого графика.

# %% [markdown]
# - **Temperature_K** - температуры в Кельвинах
# - **Luminosity**- относительная яркость
# - **Radius** -относительный радиус
# - **Absolute_magnitude** -абсолютная величина - подразумевается "Абсолютная звёздная величина" или блеск объекта
# - **Star_color** - цвет
# - **Spectral_Class** - спектральный класс
# - **Star_type** - тип от 0 до 5:<br>
#   **own Dwarf**-> Star Type = 0 <br>
#   **Red Dwarf** -> Star Type = 1 <br>
#   **White Dwarf**-> Star Type = 2 <br>
#   **Main Sequence**-> Star Type = 3 <br>
#   **Supergiant** -> Star Type = 4 <br>
#   **Hypergiant** -> Star Type = 5<br>

# %% [markdown]
# # 2

# %% [markdown]
# 2 Выполните с датафреймом следующие операции (многие операции можно совершить не одним способом, используйте все известные вам способы, поищите/придумайте новые способы) :

# %% [markdown]
# 2.1 вывод таблицы
#
# 2.2 вывод первых n элементов таблицы
#
# 2.3 вывод последних n элементов таблицы
#
# 2.4 .describe()
#
# 2.5 считывание значения конкретной ячейки (с конкретным индексом из конкретной колонки)  всеми известными вам способами
#
# 2.6 фильтрация строк по диапазону индекса
#
# 2.7 фильтрация набора данных по какому-либо условию
#
# 2.8. работа с пропущенными значениями (если они есть): удаление строк с пропущенными значениями, заполнение пропущенных значений средним значением по колонке. Если пропущенных значений нет — намеренно их "генерируете", прибивая какие-то куски данных в np.nan
#
# 2.9. создание нового поля вычисленного на основе значений других полей:
#
# 2.9.1 через выражение на базе имеющихся колонок,
#
# 2.9.2 через DataFrame.apply
#
# 2.9.3 через Series.apply
#
# 2.10 сортировка по какому-либо из полей
#
# 2.11 вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)
#
# 2.12 .value_counts()
#
# 2.13 Вывод уникальных значений колонки через .unique()
#
# 2.14 Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит

# %% [markdown]
# **Задание 2.1**

# %% [markdown]
# вывод таблицы

# %%
df=pd.read_csv('6 class csv.csv')
display(df)
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
df1 = df.rename(columns={'Temperature (K)': 'Temperature_K'})
df2=df1.rename(columns={'Luminosity(L/Lo)': 'Luminosity'})
df3=df2.rename(columns={'Radius(R/Ro)': 'Radius'})
df4=df3.rename(columns={'Absolute magnitude(Mv)': 'Absolute_magnitude'})
df5=df4.rename(columns={'Star type': 'Star_type'})
df6=df5.rename(columns={'Star color': 'Star_color'})
df7=df6.rename(columns={'Spectral Class': 'Spectral_Class'})
display(df7)
# Out:
#      Temperature_K     Luminosity     Radius  Absolute_magnitude  Star_type  \
# 0             3068       0.002400     0.1700               16.12          0
# 1             3042       0.000500     0.1542               16.60          0
# 2             2600       0.000300     0.1020               18.70          0
# 3             2800       0.000200     0.1600               16.65          0
# 4             1939       0.000138     0.1030               20.06          0
# ..             ...            ...        ...                 ...        ...
# 235          38940  374830.000000  1356.0000               -9.93          5
# 236          30839  834042.000000  1194.0000              -10.63          5
# 237           8829  537493.000000  1423.0000              -10.73          5
# 238           9235  404940.000000  1112.0000              -11.23          5
# 239          37882  294903.000000  1783.0000               -7.80          5
#
#     Star_color Spectral_Class
# ...

# %% [markdown]
# **Задание 2.2**

# %% [markdown]
# вывод первых n элементов таблицы

# %%
n=100
df7.head(n)
# Out:
#     Temperature_K     Luminosity   Radius  Absolute_magnitude  Star_type  \
# 0            3068       0.002400   0.1700               16.12          0
# 1            3042       0.000500   0.1542               16.60          0
# 2            2600       0.000300   0.1020               18.70          0
# 3            2800       0.000200   0.1600               16.65          0
# 4            1939       0.000138   0.1030               20.06          0
# ..            ...            ...      ...                 ...        ...
# 95          11250     672.000000   6.9800               -2.30          3
# 96           5112       0.630000   0.8760                4.68          3
# 97           7720       7.920000   1.3400                2.44          3
# 98          12098     689.000000   7.0100                0.02          3
# 99          36108  198000.000000  10.2000               -4.40          3
#
#       Star_color Spectral_Class
# 0            Red              M
# ...

# %% [markdown]
# **Задание 2.3**

# %% [markdown]
# вывод последних n элементов таблицы

# %%
n=10
df7.tail(n)
# Out:
#      Temperature_K  Luminosity  Radius  Absolute_magnitude  Star_type  \
# 230          24145    382993.0  1494.0               -8.84          5
# 231          38234    272830.0  1356.0               -9.29          5
# 232          32489    648430.0  1948.5              -10.84          5
# 233          27739    849420.0  1252.0               -7.59          5
# 234          21904    748490.0  1130.0               -7.67          5
# 235          38940    374830.0  1356.0               -9.93          5
# 236          30839    834042.0  1194.0              -10.63          5
# 237           8829    537493.0  1423.0              -10.73          5
# 238           9235    404940.0  1112.0              -11.23          5
# 239          37882    294903.0  1783.0               -7.80          5
#
#      Star_color Spectral_Class
# 230  Blue-white              B
# 231        Blue              O
# 232        Blue              O
# 233  Blue-white              B
# 234  Blue-white              B
# ...

# %% [markdown]
# **Задание 2.4**

# %% [markdown]
# describe()

# %% [markdown]
# Функция **describe()** возвращает некоторые общие статистические данные данных, включая среднее значение, стандартное отклонение, минимальный элемент, максимальный элемент и некоторые другие детали.

# %%
df7.describe()
# Out:
#        Temperature_K     Luminosity       Radius  Absolute_magnitude  \
# count     240.000000     240.000000   240.000000          240.000000
# mean    10497.462500  107188.361635   237.157781            4.382396
# std      9552.425037  179432.244940   517.155763           10.532512
# min      1939.000000       0.000080     0.008400          -11.920000
# 25%      3344.250000       0.000865     0.102750           -6.232500
# 50%      5776.000000       0.070500     0.762500            8.313000
# 75%     15055.500000  198050.000000    42.750000           13.697500
# max     40000.000000  849420.000000  1948.500000           20.060000
#
#         Star_type
# count  240.000000
# mean     2.500000
# std      1.711394
# min      0.000000
# 25%      1.000000
# 50%      2.500000
# 75%      4.000000
# max      5.000000

# %% [markdown]
# **Задание 2.5**

# %% [markdown]
# считывание значения конкретной ячейки (с конкретным индексом из конкретной колонки) всеми известными вам способами

# %%
df.iloc[0,1]
# Out:
# 0.0024

# %% [markdown]
# **Задание 2.6**

# %% [markdown]
#  фильтрация строк по диапазону индекса

# %%
df7[ 10 : 50 ]
# Out:
#     Temperature_K     Luminosity    Radius  Absolute_magnitude  Star_type  \
# 10           3600       0.002900   0.51000              10.690          1
# 11           3129       0.012200   0.37610              11.790          1
# 12           3134       0.000400   0.19600              13.210          1
# 13           3628       0.005500   0.39300              10.480          1
# 14           2650       0.000600   0.14000              11.782          1
# 15           3340       0.003800   0.24000              13.070          1
# 16           2799       0.001800   0.16000              14.790          1
# 17           3692       0.003670   0.47000              10.800          1
# 18           3192       0.003620   0.19670              13.530          1
# 19           3441       0.039000   0.35100              11.180          1
# 20          25000       0.056000   0.00840              10.580          2
# 21           7740       0.000490   0.01234              14.020          2
# ...

# %%
df7[df7['Temperature_K']>5000] # Температура больше 5000 K
# Out:
#      Temperature_K    Luminosity      Radius  Absolute_magnitude  Star_type  \
# 20           25000       0.05600     0.00840               10.58          2
# 21            7740       0.00049     0.01234               14.02          2
# 22            7220       0.00017     0.01100               14.23          2
# 23            8500       0.00050     0.01000               14.50          2
# 24           16500       0.01300     0.01400               11.89          2
# ..             ...           ...         ...                 ...        ...
# 235          38940  374830.00000  1356.00000               -9.93          5
# 236          30839  834042.00000  1194.00000              -10.63          5
# 237           8829  537493.00000  1423.00000              -10.73          5
# 238           9235  404940.00000  1112.00000              -11.23          5
# 239          37882  294903.00000  1783.00000               -7.80          5
#
#      Star_color Spectral_Class
# ...

# %% [markdown]
# **Задание 2.7**

# %% [markdown]
# фильтрация набора данных по какому-либо условию

# %%
df7.isna().sum() # есть ли неопределнные ячейки
# Out:
# Temperature_K         0
# Luminosity            0
# Radius                0
# Absolute_magnitude    0
# Star_type             0
# Star_color            0
# Spectral_Class        0
# dtype: int64

# %%
df7[ df7['Spectral_Class'].isin(['A','B']) ]
# Out:
#      Temperature_K    Luminosity      Radius  Absolute_magnitude  Star_type  \
# 20           25000       0.05600     0.00840               10.58          2
# 21            7740       0.00049     0.01234               14.02          2
# 23            8500       0.00050     0.01000               14.50          2
# 24           16500       0.01300     0.01400               11.89          2
# 26            8570       0.00081     0.00970               14.20          2
# ..             ...           ...         ...                 ...        ...
# 230          24145  382993.00000  1494.00000               -8.84          5
# 233          27739  849420.00000  1252.00000               -7.59          5
# 234          21904  748490.00000  1130.00000               -7.67          5
# 237           8829  537493.00000  1423.00000              -10.73          5
# 238           9235  404940.00000  1112.00000              -11.23          5
#
#      Star_color Spectral_Class
# ...

# %% [markdown]
# **Задание 2.8**

# %% [markdown]
# работа с пропущенными значениями (если они есть): удаление строк с пропущенными значениями, заполнение пропущенных значений средним значением по колонке. Если пропущенных значений нет — намеренно их "генерируете", прибивая какие-то куски данных в np.nan

# %%
for _ in range(0, 25):
    df7.iloc[np.random.randint(0,df7.shape[0]),0] = np.NaN # Добавим неизветсных в данные в случайную строку в колонку Temperature

# %%
# Добавилось
df7.isna().sum()
# Out:
# Temperature_K         24
# Luminosity             0
# Radius                 0
# Absolute_magnitude     0
# Star_type              0
# Star_color             0
# Spectral_Class         0
# dtype: int64

# %%
# Заменим неизвестные средним значением этой колонки
df7['Temperature_K']=df7['Temperature_K'].fillna(value=df7['Temperature_K'].mean())

# %%
 # теперь снова все чисто
df7.isna().sum()
# Out:
# Temperature_K         0
# Luminosity            0
# Radius                0
# Absolute_magnitude    0
# Star_type             0
# Star_color            0
# Spectral_Class        0
# dtype: int64

# %% [markdown]
# **Задание 2.9**

# %% [markdown]
#  создание нового поля вычисленного на основе значений других полей:

# %% [markdown]
# **Задание 2.9.1**

# %% [markdown]
# через выражение на базе имеющихся колонок,

# %%
# Температура в градусах Цельсия
df7['Temperature_C'] = df7['Temperature_K'] + 273.1
df7.head()
# Out:
#    Temperature_K  Luminosity  Radius  Absolute_magnitude  Star_type  \
# 0    3068.000000    0.002400  0.1700               16.12          0
# 1    3042.000000    0.000500  0.1542               16.60          0
# 2   10508.462618    0.000300  0.1020               18.70          0
# 3    2800.000000    0.000200  0.1600               16.65          0
# 4    1939.000000    0.000138  0.1030               20.06          0
#
#   Star_color Spectral_Class  Temperature_C
# 0        Red              M    3341.100000
# 1        Red              M    3315.100000
# 2        Red              M   10781.562618
# 3        Red              M    3073.100000
# 4        Red              M    2212.100000

# %% [markdown]
# **Задание 2.9.2**

# %% [markdown]
#  через DataFrame.apply

# %%
# Применение к PandasFrame
df7['Temperature_F']=df7.apply(lambda x: x['Temperature_C']*9/5+32, axis=1)
df7.head()
# Out:
#    Temperature_K  Luminosity  Radius  Absolute_magnitude  Star_type  \
# 0    3068.000000    0.002400  0.1700               16.12          0
# 1    3042.000000    0.000500  0.1542               16.60          0
# 2   10508.462618    0.000300  0.1020               18.70          0
# 3    2800.000000    0.000200  0.1600               16.65          0
# 4    1939.000000    0.000138  0.1030               20.06          0
#
#   Star_color Spectral_Class  Temperature_C  Temperature_F
# 0        Red              M    3341.100000    6045.980000
# 1        Red              M    3315.100000    5999.180000
# 2        Red              M   10781.562618   19438.812713
# 3        Red              M    3073.100000    5563.580000
# 4        Red              M    2212.100000    4013.780000

# %% [markdown]
# **Задание 2.9.3**

# %% [markdown]
# через Series.apply

# %%
# Применение к PandasSeries
df7['Absolute_magnitude_type'] = df7['Absolute_magnitude'].apply(lambda x: 'small' if x < 4 else 'big' )
df7.head()
# Out:
#    Temperature_K  Luminosity  Radius  Absolute_magnitude  Star_type  \
# 0    3068.000000    0.002400  0.1700               16.12          0
# 1    3042.000000    0.000500  0.1542               16.60          0
# 2   10508.462618    0.000300  0.1020               18.70          0
# 3    2800.000000    0.000200  0.1600               16.65          0
# 4    1939.000000    0.000138  0.1030               20.06          0
#
#   Star_color Spectral_Class  Temperature_C  Temperature_F  \
# 0        Red              M    3341.100000    6045.980000
# 1        Red              M    3315.100000    5999.180000
# 2        Red              M   10781.562618   19438.812713
# 3        Red              M    3073.100000    5563.580000
# 4        Red              M    2212.100000    4013.780000
#
#   Absolute_magnitude_type
# 0                     big
# 1                     big
# 2                     big
# 3                     big
# 4                     big

# %% [markdown]
# **Задание 2.10**

# %% [markdown]
#  сортировка по какому-либо из полей

# %%
df7.sort_values(by='Temperature_K')
# Out:
#      Temperature_K     Luminosity    Radius  Absolute_magnitude  Star_type  \
# 4           1939.0       0.000138     0.103              20.060          0
# 7           2600.0       0.000400     0.096              17.400          0
# 78          2621.0       0.000600     0.098              12.810          1
# 6           2637.0       0.000730     0.127              17.220          0
# 14          2650.0       0.000600     0.140              11.782          1
# ..             ...            ...       ...                 ...        ...
# 159        37800.0  202900.000000     6.860              -4.560          3
# 239        37882.0  294903.000000  1783.000              -7.800          5
# 231        38234.0  272830.000000  1356.000              -9.290          5
# 235        38940.0  374830.000000  1356.000              -9.930          5
# 30         39000.0  204000.000000    10.600              -4.700          3
#
#     Star_color Spectral_Class  Temperature_C  Temperature_F  \
# ...

# %% [markdown]
# **Задание 2.11**

# %% [markdown]
# вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)

# %%
statistics = ['mean', 'max', 'min', 'std', 'median']
columns = list(df7)
for col in columns[0:4]:
    print(f'for {col}')
    for stat in statistics:
        print(f' {stat} = {df7[col].agg(stat)} ')
# Out:
# for Temperature_K
#  mean = 10508.462618432384
#  max = 39000.0
#  min = 1939.0
#  std = 8598.324292014622
#  median = 9783.5
# for Luminosity
#  mean = 107188.36163460833
#  max = 849420.0
#  min = 8e-05
#  std = 179432.2449402145
#  median = 0.07050000000000001
# for Radius
#  mean = 237.15778137500004
#  max = 1948.5
#  min = 0.0084
#  std = 517.1557634028478
#  median = 0.7625
# for Absolute_magnitude
#  mean = 4.382395833333335
#  max = 20.06
#  min = -11.92
#  std = 10.53251235061617
#  median = 8.312999999999999

# %% [markdown]
# **Задание 2.12**

# %% [markdown]
# value_counts()

# %%
df7['Star_color'].value_counts()
# Out:
# Red                   112
# Blue                   55
# Blue-white             26
# Blue White             10
# yellow-white            8
# White                   7
# Blue white              3
# Yellowish White         3
# white                   3
# Whitish                 2
# Orange                  2
# yellowish               2
# Pale yellow orange      1
# White-Yellow            1
# Blue                    1
# Yellowish               1
# Orange-Red              1
# Blue white              1
# Blue-White              1
# Name: Star_color, dtype: int64

# %% [markdown]
# **Задание 2.13**

# %% [markdown]
# Вывод уникальных значений колонки через .unique()

# %%
pd.unique(df7['Star_color'])
# Out:
# array(['Red', 'Blue White', 'White', 'Yellowish White', 'Blue white',
#        'Pale yellow orange', 'Blue', 'Blue-white', 'Whitish',
#        'yellow-white', 'Orange', 'White-Yellow', 'white', 'Blue ',
#        'yellowish', 'Yellowish', 'Orange-Red', 'Blue white ',
#        'Blue-White'], dtype=object)

# %% [markdown]
# **Задание 2.14**

# %% [markdown]
#  Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит

# %%
df7_new_index = df7.set_index('Luminosity')
df7_new_index
# Out:
#                Temperature_K     Radius  Absolute_magnitude  Star_type  \
# Luminosity
# 0.002400         3068.000000     0.1700               16.12          0
# 0.000500         3042.000000     0.1542               16.60          0
# 0.000300        10508.462618     0.1020               18.70          0
# 0.000200         2800.000000     0.1600               16.65          0
# 0.000138         1939.000000     0.1030               20.06          0
# ...                      ...        ...                 ...        ...
# 374830.000000   38940.000000  1356.0000               -9.93          5
# 834042.000000   30839.000000  1194.0000              -10.63          5
# 537493.000000    8829.000000  1423.0000              -10.73          5
# 404940.000000   10508.462618  1112.0000              -11.23          5
# 294903.000000   37882.000000  1783.0000               -7.80          5
#
#               Star_color Spectral_Class  Temperature_C  Temperature_F  \
# Luminosity
# ...

# %% [markdown]
# **3**

# %% [markdown]
# 3 Продемонстрировать работу .groupby, на основе группировок в groupby вычисляете агрегатные функции по одной или нескольким колонкам. Какую информацию о данных вы получили, выполнив данную операцию? Запишите ответ в комментариях.
#
# Например, посчитать средний процент алкоголя в напитках с определенной пользовательской оценкой

# %%
# сколько звёзд каждого цвета в каждом спектральном классе
df7.groupby(['Spectral_Class', 'Star_color'])['Star_color'].count()
# Out:
# Spectral_Class  Star_color
# A               Blue White              1
#                 Blue white              2
#                 Blue-White              1
#                 Blue-white              8
#                 White                   5
#                 Whitish                 1
#                 white                   1
# B               Blue                   15
#                 Blue                    1
#                 Blue White              9
#                 Blue white              1
#                 Blue white              1
#                 Blue-white             18
#                 Whitish                 1
# F               Pale yellow orange      1
#                 White                   2
#                 White-Yellow            1
#                 Yellowish White         3
#                 white                   2
#                 yellow-white            8
# G               Red                     1
# K               Orange                  1
# ...

# %% [markdown]
# **4**

# %% [markdown]
# 4 Решейпинг данных 1Dto2D с помощью .pivot (можно подать на вход результаты агрегатов, полученных ранее через .groupby (сгруппировать по двум полям), либо прекрасно заходит сюда данные из SQL сгруппированные предварительно по 2-м полям). Какую информацию о данных вы получили, выполнив данную операцию? Запишите ответ в комментариях.

# %%
# средняя температура для каждой комбинации Color * Spectral_Class

df7_grp = df7.groupby(['Star_color', 'Spectral_Class'])['Temperature_K'].mean().reset_index()
df7_grp.pivot(index = 'Star_color', columns = 'Spectral_Class' )
df7_grp
# Out:
#             Star_color Spectral_Class  Temperature_K
# 0                 Blue              B   20534.830841
# 1                 Blue              O   18984.211781
# 2                Blue               B   10357.451163
# 3           Blue White              A    9675.000000
# 4           Blue White              B   15190.444444
# 5           Blue white              A    8747.000000
# 6           Blue white              B   12912.000000
# 7          Blue white               B   11900.000000
# 8           Blue-White              A   10357.451163
# 9           Blue-white              A   11547.307827
# 10          Blue-white              B   21293.439655
# 11              Orange              K    4287.000000
# 12              Orange              M    3749.000000
# 13          Orange-Red              K   10357.451163
# 14  Pale yellow orange              F    7230.000000
# 15                 Red              G   10357.451163
# 16                 Red              K    4015.000000
# ...

# %% [markdown]
# **5**

# %% [markdown]
# 5 Решейпинг 1Dto2D данных соединённый с группировкой / агрегацией (одним словом — сводная таблица): .pivot_table. Группируем только по категориальным полям или числовым, если уверены, что значений немного! Если значений много, можете вначале из загрубить (см. (2.9.) либо (7)).
# Перед тем как выполнять задание сформулируйте вопрос, на который собираетесь получить ответ с помощью сводной таблицы. Запишите этот вопрос в комментариях. Какую информацию о данных вы в результате получили?
# https://pbpython.com/pandas-pivot-table-explained.html

# %%
# средний радиус каждого типа звёзд определённого спектра
# без NaN подобную таблицу составить не получится, т.к. это особенность датасета
df_grp1 = df7.pivot_table(index=['Star_type'], columns=['Spectral_Class'], values='Radius', aggfunc='mean')
df_grp1[df_grp1.notnull() == True]
# Out:
# Spectral_Class            A            B         F       G          K  \
# Star_type
# 0                       NaN          NaN       NaN     NaN        NaN
# 1                       NaN          NaN       NaN     NaN        NaN
# 2                  0.010001     0.010935  0.010742     NaN        NaN
# 3                  4.662000     5.951000  1.159500     NaN     0.9165
# 4                       NaN    19.000000       NaN     NaN        NaN
# 5               1267.500000  1311.057143       NaN  1467.0  1424.5000
#
# Spectral_Class            M            O
# Star_type
# 0                  0.110015          NaN
# 1                  0.348145          NaN
# 2                       NaN          NaN
# 3                       NaN     8.057400
# 4                 46.555556    54.793103
# 5               1362.045455  1447.083333

# %% [markdown]
# **6**

# %% [markdown]
# 6 Посчитать квантили распределения какого-либо вещественного признака (с помощью numpy.quantile или numpy.percentile)

# %%
np.quantile(df7['Luminosity'], 0.99)
# Out:
# 801662.6999999996

# %% [markdown]
# **7**

# %% [markdown]
# 7 Посчитать гистограмму какого-либо вещественного признака (с помощью numpy.histogram). Значения гистограммы можете использовать как вариант в качестве загрубленного числового признака для заданий (4) или (5).

# %%
from matplotlib import pyplot as plt
import numpy as np
np.histogram(df7['Temperature_K'], bins = 10)
# Out:
# (array([98, 20, 64, 13, 12, 10,  9,  4,  5,  5], dtype=int64),
#  array([ 1939. ,  5645.1,  9351.2, 13057.3, 16763.4, 20469.5, 24175.6,
#         27881.7, 31587.8, 35293.9, 39000. ]))

# %%
h = plt.hist(df7['Temperature_K'], bins=10)
plt.show()

# %% [markdown]
# **8**

# %% [markdown]
# 8 Получить DataFrame с MultiIndex любым способом: через конструктор (в документации увидите множество видов конструкторов для создания MultiIndex с нуля), через read_sql / read_csv / read_excel, read_*, через pivot_table, через groupby или иными способами.

# %%
df8 = df7.pivot_table(index = ['Spectral_Class', 'Star_type'], columns = 'Star_color', values = 'Temperature_K').fillna(0).astype(int)
df8
# Out:
# Star_color                 Blue  Blue   Blue White  Blue white  Blue white   \
# Spectral_Class Star_type
# A              2              0      0        9675        8747            0
#                3              0      0           0           0            0
#                5              0      0           0           0            0
# B              2          17914  10357       15190       12912        11900
#                3              0      0           0           0            0
#                4          33525      0           0           0            0
#                5          26000      0           0           0            0
# F              2              0      0           0           0            0
#                3              0      0           0           0            0
# G              5              0      0           0           0            0
# K              3              0      0           0           0            0
# ...

# %% [markdown]
# **9**

# %% [markdown]
# 9 Переставить местами уровни индекса

# %%
df8.swaplevel( i = 0, j = 1, axis = 0 ).sort_index()
# Out:
# Star_color                 Blue  Blue   Blue White  Blue white  Blue white   \
# Star_type Spectral_Class
# 0         M                   0      0           0           0            0
# 1         M                   0      0           0           0            0
# 2         A                   0      0        9675        8747            0
#           B               17914  10357       15190       12912        11900
#           F                   0      0           0           0            0
# 3         A                   0      0           0           0            0
#           B                   0      0           0           0            0
#           F                   0      0           0           0            0
#           K                   0      0           0           0            0
#           O               26340      0           0           0            0
# 4         B               33525      0           0           0            0
# ...

# %% [markdown]
# **10**

# %% [markdown]
# 10 Транспонировать таблицу (или создать новую другую) с MultiIndex

# %%
df8.transpose()
# Out:
# Spectral_Class         A                   B                           F  \
# Star_type              2      3     5      2      3      4      5      2
# Star_color
# Blue                   0      0     0  17914      0  33525  26000      0
# Blue                   0      0     0  10357      0      0      0      0
# Blue White          9675      0     0  15190      0      0      0      0
# Blue white          8747      0     0  12912      0      0      0      0
# Blue white             0      0     0  11900      0      0      0      0
# Blue-White             0  10357     0      0      0      0      0      0
# Blue-white             0  11547     0      0  21866      0  20147      0
# Orange                 0      0     0      0      0      0      0      0
# Orange-Red             0      0     0      0      0      0      0      0
# Pale yellow orange     0      0     0      0      0      0      0   7230
# Red                    0      0     0      0      0      0      0      0
# ...

# %% [markdown]
# **11**

# %% [markdown]
# 11 Удалить один из уровней индекса или добавить новый уровень индекса (можно инициализированный константой)

# %%
df8.droplevel(1)
# Out:
# Star_color       Blue  Blue   Blue White  Blue white  Blue white   Blue-White  \
# Spectral_Class
# A                   0      0        9675        8747            0           0
# A                   0      0           0           0            0       10357
# A                   0      0           0           0            0           0
# B               17914  10357       15190       12912        11900           0
# B                   0      0           0           0            0           0
# B               33525      0           0           0            0           0
# B               26000      0           0           0            0           0
# F                   0      0           0           0            0           0
# F                   0      0           0           0            0           0
# G                   0      0           0           0            0           0
# K                   0      0           0           0            0           0
# ...

# %% [markdown]
# **12**

# %% [markdown]
# 12 Продемонстировать работу .merge

# %%
df7_new = pd.DataFrame({'Temperature_K': df7.Temperature_K, 'Radius': np.random.rand(df7.Temperature_K.count())})
df7_new
# Out:
#      Temperature_K    Radius
# 0      3068.000000  0.512263
# 1      3042.000000  0.389001
# 2     10508.462618  0.253630
# 3      2800.000000  0.983568
# 4      1939.000000  0.002517
# ..             ...       ...
# 235   38940.000000  0.670012
# 236   30839.000000  0.168966
# 237    8829.000000  0.794315
# 238   10508.462618  0.723377
# 239   37882.000000  0.434771
#
# [240 rows x 2 columns]

# %%
df7_merge = df7.merge(df7_new, left_on='Temperature_K', right_on='Temperature_K')
df7_merge
# Out:
#       Temperature_K   Luminosity   Radius_x  Absolute_magnitude  Star_type  \
# 0       3068.000000       0.0024     0.1700               16.12          0
# 1       3042.000000       0.0005     0.1542               16.60          0
# 2      10508.462618       0.0003     0.1020               18.70          0
# 3      10508.462618       0.0003     0.1020               18.70          0
# 4      10508.462618       0.0003     0.1020               18.70          0
# ...             ...          ...        ...                 ...        ...
# 1263   21904.000000  748490.0000  1130.0000               -7.67          5
# 1264   38940.000000  374830.0000  1356.0000               -9.93          5
# 1265   30839.000000  834042.0000  1194.0000              -10.63          5
# 1266    8829.000000  537493.0000  1423.0000              -10.73          5
# 1267   37882.000000  294903.0000  1783.0000               -7.80          5
#
#       Star_color Spectral_Class  Temperature_C  Temperature_F  \
# ...

# %% [markdown]
# **13**

# %% [markdown]
# 13 Продемонстрировать работу с .concat или append

# %% [markdown]
# Метод Pandas **Concat()** используется для объединения объектов Pandas, таких как DataFrames и Series. Мы можем передать различные параметры для изменения поведения операции конкатенации.

# %%
df7_p1 = df7[:9]
df7_p2 = df7[9:20]
df7_3 = pd.concat([df7_p1,df7_p2])
df7_3
# Out:
#     Temperature_K  Luminosity  Radius  Absolute_magnitude  Star_type  \
# 0     3068.000000    0.002400  0.1700              16.120          0
# 1     3042.000000    0.000500  0.1542              16.600          0
# 2    10508.462618    0.000300  0.1020              18.700          0
# 3     2800.000000    0.000200  0.1600              16.650          0
# 4     1939.000000    0.000138  0.1030              20.060          0
# 5     2840.000000    0.000650  0.1100              16.980          0
# 6     2637.000000    0.000730  0.1270              17.220          0
# 7     2600.000000    0.000400  0.0960              17.400          0
# 8    10508.462618    0.000690  0.1100              17.450          0
# 9     2700.000000    0.000180  0.1300              16.050          0
# 10    3600.000000    0.002900  0.5100              10.690          1
# 11   10508.462618    0.012200  0.3761              11.790          1
# 12    3134.000000    0.000400  0.1960              13.210          1
# ...

# %% [markdown]
# **14**

# %% [markdown]
# 14 Проитерировать dataframe построчно .iterrows(). Выполните что-то имеющее смысл внутри цикла

# %%
# используем iterrows для получения каждого элемента строк в датафрейме.
for i  in df7_3.iterrows():
    print(i)
# Out:
# (0, Temperature_K               3068.0
# Luminosity                  0.0024
# Radius                        0.17
# Absolute_magnitude           16.12
# Star_type                        0
# Star_color                     Red
# Spectral_Class                   M
# Temperature_C               3341.1
# Temperature_F              6045.98
# Absolute_magnitude_type        big
# Name: 0, dtype: object)
# (1, Temperature_K               3042.0
# Luminosity                  0.0005
# Radius                      0.1542
# Absolute_magnitude            16.6
# Star_type                        0
# Star_color                     Red
# Spectral_Class                   M
# Temperature_C               3315.1
# Temperature_F              5999.18
# Absolute_magnitude_type        big
# Name: 1, dtype: object)
# (2, Temperature_K              10508.462618
# Luminosity                       0.0003
# Radius                            0.102
# Absolute_magnitude                 18.7
# ...
